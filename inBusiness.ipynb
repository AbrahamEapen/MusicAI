# %%
from music21 import *

# %%
c = chord.Chord("C4 E4 G4")
c.isConsonant()
# Out:
# True

# %%
c.show('midi')
# Out:
#                 <div id='midiPlayerDiv7'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv7');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
import notebook
notebook.nbextensions.check_nbextension('usability/sphinx-markdown', user=True)
# Out:
# False

# %%
s = corpus.parse('bach/bwv65.2.xml')

# %%
s.analyze('key')
# Out:
# <music21.key.Key of a minor>

# %%
#s.show()

# %%
#play that music!
s.show('midi')
# Out:
#                 <div id='midiPlayerDiv2373'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv2373');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
print(s)
# Out:
# <music21.stream.Score 0x10d5b2da0>

# %%
test = s.parts[0]
test.measures(1, 100).plot()

# %%
import pandas as pd

# %%
a = test.measures(1, 100)

# %%
df = pd.DataFrame(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-cefcf89152ae> in <module>()
# ----> 1 df = pd.DataFrame(a)
#
# /Users/jeffreycoen/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     352                                          copy=False)
#     353             else:
# --> 354                 raise ValueError('DataFrame constructor not properly called!')
#     355
#     356         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!
